# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
### YOUR CODE HERE ###
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# импорт всех данных в df
progress_phases = pd.read_csv('progress_phases.csv', sep = ',', parse_dates=['start_date' ,'finish_date'])
progresses = pd.read_csv('progresses.csv', sep = ',')
course_contents = pd.read_csv('course_contents.csv', sep = ',')
courses = pd.read_csv('courses.csv', sep = ',')
students = pd.read_csv('students.csv', sep = ',', parse_dates=['birthday'], dayfirst = False)

# объединяем df в основной массив
m1 = progress_phases.merge(progresses, left_on='progress_id', right_on='id', how='left')
m2 = m1.merge(courses, left_on='course_id', right_on = 'id', how='left')
main = m2.merge(course_contents, on=['course_id', 'module_number', 'lesson_number'], how = 'left')

# %%
# общее количество курсов в датасете
main.course_id.unique().shape[0]
# Out:
# 15

# %%
# количество модулей на каждом курсе. 
n_modules = main.groupby(['course_id','title'])['module_number'].agg('nunique').reset_index()
# посмотрим какие курсы самые длинные и короткие исходя из количества модулей. Возможно пригодиться позднее
n_modules.sort_values(by='module_number')
# Out:
#                            course_id                                title  \
# 7   abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 11  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 6   943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 8   ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 5   842218e7c983795934bbe4533c0888c8             SMM-маркетолог от А до Я
# 1   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 2   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 4   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 10  c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 9   bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 14  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# 13  e3a0df907589d56692b5cb561fd90d87                Веб-дизайн с нуля 2.0
# ...

# %%
# количество уроков в каждом модуле на каждом курсе,
n_lessons = main.groupby(['course_id','title','module_number'])['lesson_number'].agg('nunique').reset_index()
# остортируем по количеству уроков для выявления возможных интересных наблюдений.
n_lessons.sort_values(by='lesson_number')
# медианное количество уроков в модуле на каждом курсе
n_lessons.groupby(['course_id','title'])['lesson_number'].agg('median').reset_index().sort_values(by='lesson_number', ascending=False)
# Out:
#                            course_id                                title  \
# 6   943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 4   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 7   abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 14  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# 9   bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 5   842218e7c983795934bbe4533c0888c8             SMM-маркетолог от А до Я
# 1   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 8   ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 10  c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 11  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 13  e3a0df907589d56692b5cb561fd90d87                Веб-дизайн с нуля 2.0
# 12  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# ...

# %%
# количество учеников на каждом курсе
n_students = main.groupby(['course_id','title'])['student_id'].agg('nunique').reset_index()
# описательная статистика и топ по количеству студентов
n_students.describe() 
n_students.sort_values(by='student_id', ascending=False)
# Out:
#                            course_id                                title  \
# 9   bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 13  e3a0df907589d56692b5cb561fd90d87                Веб-дизайн с нуля 2.0
# 7   abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 10  c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 12  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 14  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# 11  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 8   ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 4   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 1   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 3   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 0   04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# ...

# %%
# минимальный, максимальный, средний, медианный возраст студентов
# в начале загрузим данные с днями рождениями и проеобразуем их в timestamp
students = pd.read_csv('students.csv', sep = ',')
students['birthday'] = pd.to_datetime(students['birthday'], errors = 'coerce')
# Получим возраст из даты рождения
today = pd.datetime.today()
students['age'] = students['birthday'].apply(lambda x: today.year - x.year - ((today.month, today.day) < (x.month, x.day)))
# удаляем строки с датой рождения > текущей даты, чтобы избавиться от отрицательного возраста(явно некорректное заведение ДР)
students.drop(students[students.birthday > today].index, inplace=True)
# посчитаем минимальный, максимальный, средний, медианный возраст студентов
students_age = students['age'].agg(['min', 'max', 'mean', 'median'])
students_age
# Out:
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\4036249320.py:6: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   today = pd.datetime.today()
# min         2.000000
# max       138.000000
# mean       31.433314
# median     31.000000
# Name: age, dtype: float64

# %%
# минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# в начале добавим возраст в основной df
main = main.merge(students, how='left', left_on = 'student_id', right_on = 'id')
# сгруппируем по курсам и посчитаем минимальный, максимальный, средний, медианный возраст
age_students = main.groupby(['course_id','title'])['age'].agg(['min', 'max', 'mean', 'median']).reset_index()
age_students
# Out:
#                            course_id                                title  \
# 0   04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 1   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 2   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 3   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 4   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 5   842218e7c983795934bbe4533c0888c8             SMM-маркетолог от А до Я
# 6   943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 7   abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 8   ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 9   bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 10  c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 11  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# ...

# %%
# отсоритруем по медианному возрасту
age_students.sort_values(by='median', ascending = False)
# Out:
#                            course_id                                title  \
# 8   ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 1   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 9   bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 11  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 12  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 0   04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 4   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 6   943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 2   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 5   842218e7c983795934bbe4533c0888c8             SMM-маркетолог от А до Я
# 7   abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 14  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# ...

# %%
# Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
data = n_students
fig, ax = plt.subplots(figsize=(15,7))

g = sns.barplot(data=data, x='title', y='student_id', ax=ax, ci=None, hue='title', dodge=False)
g.set_title('Количество студентов на каждом курсе')
g.set_xlabel('Курс')
g.set_ylabel('Количество студентов')
g.set_xticklabels(g.get_xticklabels(), rotation = 45, ha = 'right')
g.legend_.remove()
plt.show()

# %%
from numpy import median
# добавляем данные по сфере курса и сортируем
data = n_students.merge(courses[['id', 'field']], how='left', left_on = 'course_id', right_on = 'id').sort_values(by = 'student_id')
# строим горизонтальный bar-chart, отражающий количество студентов на каждом курсе
fig, ax = plt.subplots(figsize=(15,7))

g = sns.barplot(data=data, y='title', x='student_id', ax=ax, ci=None, hue='field', alpha=0.1, dodge=False)
g.set_title('Количество студентов на каждом курсе')
g.set_ylabel('Курс')
g.set_xlabel('Количество студентов')
g.set_yticklabels(g.get_yticklabels(), ha = 'right')
plt.axvline(n_students['student_id'].median(), alpha=0.2, color = 'black', label='медиана')
g.legend(bbox_to_anchor=(1.3, 0.75))
plt.box(on=False)
plt.show()

# %% [markdown]
# Программа состоит из 15 курсов. Количество модулей внутри курсов варьируется от 8 до 21, в среднем составляет 15.
# В каждом модуле от 1 до 29 уроков. Самым продолжительными по количеству уроков внутри модулей являются курсы "Интернет-маркетолог от Ingate": 3 из 4-х модулей в топе относятся к этому курсу.
# Количество студентов на курсах от 506 от 2168. При этом из 15 курсов топ-3 самых популярных имеют свыше 2000 студентов: "Интернет-маркетолог от Ingate", "Веб-дизайн с нуля 2.0", "Веб-вёрстка для начинающих 2.0". На остальных курсах обучается значительно меньше стундентов: в 10 курсах кол-во студентов менее 1000, медианное значение составляет 782 и заметно меньше среднего (1062), что говорит о неравномерном распределении учащихся по курсам. Популярность вышеуказаннных курсов показывает, что стоит обратить внимание на них и, возможно, направить ресурсы развития на них в первую очердь.
# Минимальный возраст студентов даже после удаления явно некорректных данных о дате рождения(позднее чем текущая дата) равен 1(младенец), максимальный 136(человек, родившийся в 19-м веке) - оба крайних значения говорят об оставшихся в данных неправильно заведенных дат рождения и заставляют задуматься о внедрении проверок корректности заведения дат рождения пользователями. Несмотря на это, медианное и среднее значения возраста близки: 29 и 30 соответственно, что позволяет достаточно достоверно определить возраст целевой аудитории учащихся.
# Распределение возраста учащихся по курсам однородное - нет сильных отклонений от среднего возраста всех учащихся, однако можно обратить внимание на курсы с минимальным и максимальным медианным/средним возрастом: 28 лет для курса "Веб-дизайн с нуля 2.0" и 34 для курса "Эксель Базовый". Более молодые студенты выбирают один из самых популярных курсов, наверняка, рассчитывая попасть в тренд на рынке digital профессий, а более зрелые стремятся повысить свою квалификацию в классическом экселе, чтобы быть более эффективными на любом месте работы, т.к. эксель используется повсеместно.

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
## YOUR CODE HERE ###
# 2.1. Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# так как нужны помесячные данные по количеству студентов, добавим столбец с месяцом и годом "start_date"  в основной df
main['year'] = main['start_date'].apply(lambda x: x.year)
main['month'] = main['start_date'].apply(lambda x: x.month)
# выберем уроки только с ДЗ и найдем первый модуль в каждом курсе, в котором встречается ДЗ
first_mod = main[main['is_homework']==True].groupby('title')['module_number'].agg('min').reset_index()
# сохраним номера модулей с первым ДЗ для каждого курса в словарь
d_mod = dict(first_mod.values)

# для проверки, что ДЗ именно первое в курсе, добавим столбец с номером модуля с первым ДЗ в основной df
main_st_count_1 = main[main['is_homework']==True]
main_st_count_1['first_hw_mod_n'] = main_st_count_1.title.map(d_mod)
# посчитаем количество студентов для какждого курса и модуля с первым ДЗ по месяцам
main_st_count_1 = main_st_count_1[main_st_count_1['module_number']==main_st_count_1['first_hw_mod_n']].groupby(
    ['title', 'year', 'month','student_id'])['start_date'].first().reset_index()
main_st_count_2 = main_st_count_1.groupby(['title', 'year', 'month'])['start_date','student_id'].agg(
    {'start_date':'min','student_id':'count'}).reset_index()
main_st_count_2
# Out:
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\4097176041.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_st_count_1['first_hw_mod_n'] = main_st_count_1.title.map(d_mod)
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\4097176041.py:17: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   main_st_count_2 = main_st_count_1.groupby(['title', 'year', 'month'])['start_date','student_id'].agg(
#                              title  year  month  \
# 0                    Excel Базовый  2018      2
# 1                    Excel Базовый  2018      3
# 2                    Excel Базовый  2018      5
# 3                    Excel Базовый  2018      6
# ...

# %%
# 2. строим line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
g = sns.FacetGrid(main_st_count_2, col='title', height=3, aspect=2, col_wrap=3)
g.map(sns.lineplot, 'start_date', 'student_id')

plt.show()

# %%
# 3. строим line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
fig, ax = plt.subplots(figsize=(15,7))

g = sns.lineplot(data=main_st_count_2, y='student_id', x='start_date', ax=ax, ci=None, hue='title')
g.set_title('Прирост студентов на каждом курсе')
g.set_ylabel('Прирост студентов')
g.set_xlabel('Дата начала курса')
plt.show()

# %%
# 4. Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# создадим df с данными только с выполненными домашними работами 
main_2_4 = main[(main['is_homework']==True) & (main['status']=='done')]

# добавим столбец с разницей между датами начала и конца выполнения ДЗ в месяцах 
main_2_4['prd_to_fill'] = main_2_4.apply(
    lambda x: pd.period_range(start=x.start_date, end=x.finish_date, freq='M'), axis = 1)
# полученные списки месяцев между датами начала и конца выполнения ДЗ разобьем/скопируем в ячейки для их учета
main_2_4 = main_2_4.explode('prd_to_fill')
# сгруппируем данные 
main_2_4 = main_2_4.groupby(['title', 'prd_to_fill'])['progress_id', 'start_date'].agg(
    {'progress_id':'count', 'start_date':'max'}).reset_index()
# второй вариант со сводной таблицей main_2_4.pivot_table('progress_id', 'prd_to_fill', 'title', aggfunc=pd.Series.nunique, fill_value=0)
main_2_4
# Out:
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\3184412599.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_2_4['prd_to_fill'] = main_2_4.apply(
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\3184412599.py:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   main_2_4 = main_2_4.groupby(['title', 'prd_to_fill'])['progress_id', 'start_date'].agg(
#                              title prd_to_fill  progress_id  \
# 0                    Excel Базовый     2018-02           35
# 1                    Excel Базовый     2018-03            6
# 2                    Excel Базовый     2018-04           12
# ...

# %%
# 2.5  Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы

g = sns.FacetGrid(main_2_4, col='title', height=3, aspect=2, col_wrap=3)
g.map(sns.lineplot, 'start_date', 'progress_id')
for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(90)
plt.show()

# %%
# 2.6 Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
fig, ax = plt.subplots(figsize=(15,7))

g = sns.lineplot(data=main_2_4, y='progress_id', x='start_date', ax=ax, ci=None, hue='title')
g.set_title('Количество прогрессов по месяцам на каждом курсе')
g.set_ylabel('Количество прогрессов')
g.set_xlabel('Месяц')
plt.show()

# %% [markdown]
# **2.7**
#
# **Выводы по нагрузке преподавателей на основе данных о приросте:**
#
# Для начала разделим курсы по цифре относительно стабильного прироста студентов: курсы, где прирост колебался около 50чел/мес и ниже, и курсы с приростом 100чел/мес и выше. Из 15 к популярным быстрорастущим курсам можно отнести 4 курса: Интернет-маркетолог от Ingate, Веб-вёрстка для начинающих 2.0, Веб-дизайн с нуля 2.0 и Java-разработчик c нуля. Это курсы-лидеры по числу прироста студентов, поэтому нагрузка на преподавателей может быть повышенная и постоянно растет высокими по сравнению с другими курсами темпами. Возможно, стоит предусмотреть дополнительных преподователей по этим направлениям. В качестве альтернативы набора новых преподавателей и меры экономии, по двум из вышеуказанных курсов (Веб-дизайн с нуля 2.0 и Java-разработчик c нуля) можно перераспределить преподавателй с других версий этих направлений, прирост по которым спадает или практически отсутствует (Веб-дизайн Базовый и Java-разработчик). По курсам с невысокими темпами прироста (+/- 50) можно отметить, что по ним наблюдается тренд на снижение прироста студентов в 2019 году(популярность курсов падает).
#
# **Выводы по нагрузке преподавателей на основе данных о количестве прогрессов:**
#
# Топ-4 курса по максимальному количеству прогрессов (Свыше 500 прогрессов в месяц) повторяют лидеров по приросту: Интернет-маркетолог от Ingate, Веб-вёрстка для начинающих 2.0, Веб-дизайн с нуля 2.0 и Java-разработчик c нуля. Это дополнительно подтверждает повышенную нагрузку  на этих курсах на основе данных о приросте. Все остальные курсы на протяжении всего времени были ниже отметки 500 прогрессов в месяц.
# Если посмотреть чуть подробнее ТОП-4 курса по нагрузке, можно отметить, что продолжительность и интенсивность нагрузки у них была разной:
# - повышенная нагрузка на преподавателей на курсе Веб-дизайн с нуля 2.0 была самой продолжительной (почти 2 года свыше 500) и интенсивной (свыше 1500 прогрессов в месяц на протяжении полугода)
# - такой же продолжительной, но менее интенсивной (в среднем 600 - 700 прогрессов) была нагрузка на курсе Интернет-маркетолог от Ingate
# - на остальных 2-х курсах (Веб-вёрстка для начинающих 2.0 и Java-разработчик c нуля) нагрузка свыше 500 в месяц наблюдалась совсем непродолжительное время 2-3 месяца
#
# Для того, чтобы дополнительно утончить, насколько нагрузка свыше 500 прогрессов и свыше 100 приростов была высокой, необходимы дополнительные данные по учителям: например, количество проверенных учителями заданий и среднее время на проверку одного задания.
#
# **Общее и для приростов и для прогрессов:** в течение последних 3-ех месяцев (2019-05 - 2019-07) наблюдось снижение обоих показателей по всем курсам, что может быть тревожным показателем для продюссеров.

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
### YOUR CODE HERE ###
# 3.1 Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля
# создадим 2 df с первой и последней датой ДЗ для каждого студента в каждом модуле
main_3_1s = main[main['is_homework']==True].groupby(['title', 'module_number', 'student_id'])['start_date'].min().reset_index()
main_3_1f = main[main['is_homework']==True].groupby(['title', 'module_number', 'student_id'])['finish_date'].max().reset_index()
# объединим их и уберем некорреткные данные, где дата окончания меньше даты начала или равна ей
main_3_1j = main_3_1s.merge(main_3_1f, on=['title', 'module_number', 'student_id'], how='left').dropna()
main_3_1j = main_3_1j.drop(main_3_1j[(
    main_3_1j['finish_date'] < main_3_1j['start_date']) | (main_3_1j['finish_date'] == main_3_1j['start_date'])].index)
# посчитаем разницу в днях и преобразуем их в число с округлением до 2-х знаков
main_3_1j['days_spent'] = main_3_1j['finish_date'] - main_3_1j['start_date']
main_3_1j['days_spent'] = main_3_1j['days_spent'].agg(lambda x: round(x / np.timedelta64(1, 'D'), 2))
# посчитаем мин, макс, ср, мед
main_3_1 = main_3_1j.groupby(['title', 'module_number'])['days_spent'].agg(['min', 'max', 'mean', 'median'])
main_3_1
# Out:
#                                               min     max       mean  median
# title                         module_number
# Excel Базовый                 1              0.04  183.75   6.044427   2.335
#                               2              0.04  184.27   4.348980   1.875
#                               3              0.02   89.13   3.449164   1.510
#                               4              0.07  327.55  11.036522   3.250
#                               5              0.06  175.55   7.454586   3.085
# ...                                           ...     ...        ...     ...
# Руководитель digital-проектов 12             0.00  211.57  23.095802   7.930
#                               13             0.00  246.84  28.996290  13.800
#                               14             0.00  199.14  16.437193   8.890
#                               15             0.00  132.21   7.439474   2.840
#                               16             0.00  355.63  20.688039   7.140
#
# ...

# %%
g = sns.FacetGrid(main_3_1.reset_index(), col='title', height=3, aspect=2, col_wrap=3)
g.map(sns.lineplot, 'module_number', 'median')

plt.show()

# %%
# 3.3 медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# добавим месяц и год по дате окончания в основной массив, возьмем только выполненные ДЗ и как в п.3.2 очистим данные
main['year'] = main['finish_date'].apply(lambda x: x.year)
main['month'] = main['finish_date'].apply(lambda x: x.month)
main_3_3 = main[(main['is_homework']==True) & (main['status']=='done')]
main_3_3.drop(main_3_3[(
    main_3_3['finish_date'] < main_3_3['start_date']) | (main_3_3['finish_date'] == main_3_3['start_date'])].index)
# посчитаем дельту в днях и медиану по курсам
main_3_3['delta'] = (main_3_3['finish_date'] - main_3_3['start_date']) / np.timedelta64(1, 'D')
main_3_3.groupby(['title', 'month'], as_index=False)['delta'].median()
# Out:
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\2749266733.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_3_3['delta'] = (main_3_3['finish_date'] - main_3_3['start_date']) / np.timedelta64(1, 'D')
#                              title  month      delta
# 0                    Excel Базовый    1.0   2.099530
# 1                    Excel Базовый    2.0   2.240738
# 2                    Excel Базовый    3.0   2.828454
# 3                    Excel Базовый    4.0   1.883787
# 4                    Excel Базовый    5.0   2.580251
# ..                             ...    ...        ...
# 166  Руководитель digital-проектов    8.0  12.747989
# 167  Руководитель digital-проектов    9.0  10.272937
# ...

# %%
# 3.4 построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам.
fig, ax = plt.subplots(figsize=(15,7))

g = sns.lineplot(data=main_3_3, y='delta', x='month', ax=ax, ci=None, hue='title')
g.set_title('Время выполнения ДЗ по месяцам на каждом курсе')
g.set_ylabel('Значение медианы')
g.set_xlabel('Месяц')
plt.show()

# %%
# построим график средней и медианы для большей наглядности
main_3_3.groupby('month')['delta'].agg(['mean', 'median']).plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# ### **3.5**
#
# Исходя из данных о длительности выполнения ДЗ по модулям, все курсы можно разделить на 2 группы:
# - курсы, в которых длительность(=сложность) повышыется по мере ближения к концу, такие как Веб-разработчик, Веб-дизайн Базовый, Анимация интерфейсов и PHP-разработчик с 0 до PRO. Часть 1. Это выглядит логично, потому что к концу курсов появляются более объемные эжзамены и курсовые. Возможно, стоит обратить внимание на те, где выполнение удлиняется в разы очень быстро(в последних 2-3-х модулях: Веб-разработчик и PHP-разработчик с 0 до PRO. Часть 1. Такой резкий скачок может демотивировать студентов и может говорить о том, что ранеее выполненные модули не полностью подготовили студента к "боевым" задачам.
# - курсы с равномерной длительностью выполнения ДЗ. Таких большинство, что хорошо, т.к. когда студент входит в стабилный ритм и не встречает в разы более сложных задач, чем те, которые он выполнял ранее, то он получает бОльшее удовлетворение и мотивацию от учебы.
#
# Отдельно необходимо отметить модуль UX-дизайн, где длительность выполнения ДЗ резко возрастает в середине курса и падает ближе к его концу. Он выбивается из всех курсов. Возможно стоит перегруппировать модули, чтобы обучение шло по нарастающей сложности, а не демотивировало студентов сложными ДЗ в первой половине курса.
#
# Сезонность
#
# Можно отметить 2 всплеска срока выполнения ДЗ по всем курсам: в мае, в августе-октябре. Первый, скорее всего, связан с майскими праздниками, а второй - с периодом отпуском.

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
### YOUR CODE HERE ###
# создадим 2 фрейма с необходимым количеством начавших/завершивших ДЗ в каждом модуле
main = main.sort_values(by=['title', 'module_number', 'lesson_number'])
main_4_1_s = main[(main['is_homework']==True)]
main_4_1_s = main_4_1_s.groupby(['title', 'module_number', 'module_title', 'lesson_number'], as_index=False)['student_id'].count()
main_4_1_s = main_4_1_s.groupby(['title', 'module_number','module_title'], as_index=False)['student_id'].first()
main_4_1_d = main[(main['is_homework']==True) & (main['status']=='done')]
main_4_1_d = main_4_1_d.groupby(['title', 'module_number', 'lesson_number'], as_index=False)['student_id'].count()
main_4_1_d = main_4_1_d.groupby(['title', 'module_number'], as_index=False)['student_id'].first()
# объединим их в один фрейм, сдвинем на 1 строку вниз и посчитаем
main_4_1 = main_4_1_s.merge(main_4_1_d, on=['title', 'module_number'], how='left')
main_4_1['student_id_y'] = main_4_1['student_id_y'].shift(1, fill_value=0) 
main_4_1 = main_4_1.drop(main_4_1[main_4_1['module_number']==1].index)
main_4_1['converse'] = main_4_1['student_id_x'] / main_4_1['student_id_y']
main_4_1
# Out:
#                              title  module_number  \
# 1                    Excel Базовый              2
# 2                    Excel Базовый              3
# 3                    Excel Базовый              4
# 4                    Excel Базовый              5
# 5                    Excel Базовый              6
# ..                             ...            ...
# 186  Руководитель digital-проектов             12
# 187  Руководитель digital-проектов             13
# 188  Руководитель digital-проектов             14
# 189  Руководитель digital-проектов             15
# 190  Руководитель digital-проектов             16
#
#                                           module_title  student_id_x  \
# 1              Основной функционал Excel (продолжение)           434
# 2                    Формулы и функции Excel. Введение           398
# 3    Формулы и функции Excel. Продолжаем работать с...           345
# 4       Формулы и функции Excel. Более сложные формулы           298
# ...

# %%
# 4.2
data = main_4_1
fig, ax = plt.subplots(figsize=(15,7))

g = sns.barplot(data=data, x='title', y='converse', ax=ax, ci=None, hue='module_number')
g.set_title('Конверсия студентов из модуля в модуль по курсам')
g.set_xlabel('Курс')
g.set_ylabel('Значение конверсии')
g.set_xticklabels(g.get_xticklabels(), rotation = 45, ha = 'right')
plt.show()

# %%
# 4_1. дополнительная цифровая аналитика
main_4_1.groupby(['title'])['converse'].agg(['median', 'mean', 'min', 'max'])
# 4_1. дополнительные графики по курсам с пропусками в данных о конверсии 
# main_4_1_s[(main_4_1_s['title']=='UX-дизайн') | (main_4_1_s['title']=='Java-разработчик c нуля')]
# Out:
#                                        median      mean       min        max
# title
# Excel Базовый                        0.981883  0.974661  0.891473   1.026882
# Java-разработчик                     1.011561  0.997445  0.875878   1.105263
# Java-разработчик c нуля              0.766337  0.816986  0.607143   1.080000
# JavaScript с нуля                    1.000000  1.013623  0.950000   1.173913
# PHP-разработчик с 0 до PRO. Часть 1  1.055556  1.079474  0.855305   1.307692
# SMM-маркетолог от А до Я             0.958753  1.595499  0.564356   5.055556
# UX-дизайн                            0.989039  1.017690  0.957746   1.153846
# Анимация интерфейсов                 0.985915  0.933826  0.085714   1.210526
# Веб-вёрстка для начинающих 2.0       1.033582  1.025724  0.925000   1.081250
# Веб-дизайн PRO 2.0                   1.014929  0.994699  0.905923   1.052632
# Веб-дизайн Базовый                   1.007883  1.817032  0.954802  10.710526
# ...

# %%
# 4.3 добавим данные по сфере курса, соответствующий каждой сфере цвет для вывода на графике и столбец "Номер+ название модуля"
d_field = dict(courses[['title', 'field']].values)
main_4_1['field'] = main_4_1.title.map(d_field)
main_4_1['color'] = main_4_1.field.map(dict(zip(list(main_4_1.field.unique()), ['red', 'green', 'blue', 'darkviolet']) ))
main_4_1['y_mod_name'] = main_4_1[['module_number','module_title']].values.tolist()
main_4_1['y_mod_name'] = main_4_1['y_mod_name'].apply(lambda x: str(x))
main_4_1
# Out:
#                              title  module_number  \
# 1                    Excel Базовый              2
# 2                    Excel Базовый              3
# 3                    Excel Базовый              4
# 4                    Excel Базовый              5
# 5                    Excel Базовый              6
# ..                             ...            ...
# 186  Руководитель digital-проектов             12
# 187  Руководитель digital-проектов             13
# 188  Руководитель digital-проектов             14
# 189  Руководитель digital-проектов             15
# 190  Руководитель digital-проектов             16
#
#                                           module_title  student_id_x  \
# 1              Основной функционал Excel (продолжение)           434
# 2                    Формулы и функции Excel. Введение           398
# 3    Формулы и функции Excel. Продолжаем работать с...           345
# 4       Формулы и функции Excel. Более сложные формулы           298
# ...

# %%
# строим 15 графиков
for title in list(main_4_1.title.unique()):
    data = main_4_1.sort_values(by=['title','module_number'], ascending = False)[main_4_1['title']==title]
    fig, ax = plt.subplots(figsize=(6,3))
    color = main_4_1[main_4_1['title'] ==title]['color'].unique()
    field = main_4_1[main_4_1['title'] ==title]['field'].unique()
    ax.barh(data['y_mod_name'], data['converse'], alpha=0.1, label = field, color=color)
    ax.set_title('Конверсия модулей в курсе {}'.format(title))
    ax.axvline(x=main_4_1[main_4_1['title']==title]['converse'].median())
    ax.legend(bbox_to_anchor=(1, 0.6))
# Out:
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\4024335436.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = main_4_1.sort_values(by=['title','module_number'], ascending = False)[main_4_1['title']==title]
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\4024335436.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = main_4_1.sort_values(by=['title','module_number'], ascending = False)[main_4_1['title']==title]
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\4024335436.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = main_4_1.sort_values(by=['title','module_number'], ascending = False)[main_4_1['title']==title]
# C:\Users\ismik\AppData\Local\Temp\ipykernel_13652\4024335436.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %% [markdown]
# 4.4
# Первое, что бросается в глаза при анализе графиков - это большое количество пропусков в данных на курсах по дизайну. В остальных курсах подобного не отмечается. Возможно, это происходит из-за большого количества незавершенных ДЗ (из-за деление на ноль завершенных ДЗ) и косвенно подтверждает проблему, которую выявили при анализе медианного времени выполнения ДЗ (см. вывод 3.5). Однако, при более подробном рассмотрении (просмотр выполненных и начатых ДЗ) оказывается, что данные отсутствуют.
#
# Вторым наблюдением является самая низкая конверсия на курсе "Java-разработчик c нуля". Если у остальных курсов конверсия близка к 1, то у "Java-разработчик c нуля" медианная конверсия 0.76.
#
# Также можно отметить, что конверсия в среднем имеет тенденцию к росту ближе к концу всех курсов (последних модулей).

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %% [markdown]
# *С учетом того, что оценок за выполненные задания студентам не ставят, единственными индикаторами успеваемости могут быть: студенты, не выполнившие задания (статус fail), и время выполнения ДЗ/прохождение модуля.
# Попробуем найти студентов, не выполнивших задания*

# %%
### YOUR CODE HERE ###
# соотношение завершивших и начавших ДЗ для каждого модуля - посмотреть какой процент студентов не заканчивал ДЗ. Аналогично для каждого курса 
main_5_s = main[(main['is_homework']==True) & (main['status'] !='done') & (main['status'] !='fail')].sort_values(['title', 'module_number'])
main_5_s = main_5_s.groupby(['title', 'module_number', 'student_id'], as_index=False)['progress_id'].agg(lambda x:x)
main_5_f = main[(main['is_homework']==True) & (main['status'] =='fail')]
main_5_f = main_5_f.groupby(['title', 'module_number', 'student_id'], as_index=False)['progress_id'].agg(lambda x:x)
main_5 = main_5_s.merge(main_5_f[['title', 'module_number', 'student_id']], on=['title', 'module_number', 'student_id'], how='inner')

main_5.groupby(['student_id'])['module_number', 'title'].agg(lambda x:x)
# Out:
# <ipython-input-42-5c52ffa832d3>:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   main_5.groupby(['student_id'])['module_number', 'title'].agg(lambda x:x)
#                                   module_number                    title
# student_id
# 0ba029d1ed51f944546d4b7f8f5447aa              4  Java-разработчик c нуля
# 0ba5e61ea012b0eddc9f88df22b4fcad              5  Java-разработчик c нуля
# 10d60d5bd2510fedc5d64b30cfdd3b9c              5  Java-разработчик c нуля
# 1ac58b48ed96e5e8620cbcf821f7c9ca              8  Java-разработчик c нуля
# 1d0777c4f014379fef5c72c4a583f237              6  Java-разработчик c нуля
# 3c65f72fc4a9528b119e2af3caa255c4              9  Java-разработчик c нуля
# 44f421c10cb220d877d2c3dcfa5457f6              4       Веб-дизайн PRO 2.0
# 551274f4f9f0dc62a0b89bdbf6e07870              5  Java-разработчик c нуля
# ...

# %% [markdown]
# *Студентов, не выполнивших ДЗ, всего двадцать. Каждый из них не выполнил ДЗ всего один раз в одном модуле, поэтому нельзя утверждать, что курс или модуль им не "дался", т.к. наблюдение всего одно по каждорму студенту
# Попробуем найти студентов, которые слишком долго проходят модули, по сравнению с другими.*

# %%
# возьмем DF из третьего задания с продолжительностью выполнения каждого модуля и выберем топ-3 студента, кто проходил модуль дольше всего)
main_5_hwl = main_3_1j.sort_values(by=['title', 'module_number', 'days_spent'], ascending=False)
main_5_hwl.groupby(['title', 'module_number'])['student_id', 'days_spent'].apply(lambda x: x.nlargest(3, 'days_spent')).reset_index()
# найдем студентов, которые систематически входят в антилидеры по срокам прохождения модулей
main_5_hwl.groupby(['title','student_id'])['module_number'].count().sort_values(ascending=False)
# Out:
# <ipython-input-100-547dc69fafce>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   main_5_hwl.groupby(['title', 'module_number'])['student_id', 'days_spent'].apply(lambda x: x.nlargest(3, 'days_spent')).reset_index()
# title                          student_id
# Интернет-маркетолог от Ingate  651b27f3a027bc0028df4fbd117d1524    18
#                                f15d37b4cc4223187d643dbab0f7bb11    18
#                                4e97bda62fb0b208c9a49d272866020d    18
#                                b1c05fcc8769f80968958e22197a4dfa    18
#                                0a3aeea977a4501655eb6e3a526ad381    18
#                                                                    ..
# UX-дизайн                      56e39d635870826b2bf7774e163f3802     1
#                                568869640e11edb63c11edf6be4666ae     1
# Интернет-маркетолог от Ingate  5d72a47b43a43c055b801335c83d670d     1
# ...

# %%
# если учесть, что количество модулей варьируется от 8 до 21, то есть студенты, которые слишком долго проходили модули даже не на одном и не на двух курсах
main_5_hwl.groupby(['student_id'])['module_number'].count().sort_values(ascending=False).head(20)
# Out:
# student_id
# 40217d80fbfb852beb0b6a896c86ad38    54
# 84f56692cdb41e40cfa41c6345f439c2    52
# b82b8296bba4fb55a82f8ad95faf815b    50
# f637b158d5720f6e50da87ac620a9c82    48
# 20656833a49c0d951f49a42280f6ee0f    48
# 1310fa586646c93fe5ecdd6e578ea2c9    48
# 38cfde7ce7f464b328a8240c4c8b46cd    47
# f1ee750ba369f122982ef490869a1617    47
# bda333fed381faada5c2745f3a583c47    44
# cc7186542f9d3ea846a3e993b2461177    44
# 9bcaa1e03111b10cdd29ebef194fc4f2    43
# a83efc46b6bc6e718e147a4f3dc526ee    42
# 3cd0c5bfc9d001950e79f88be5f8d571    42
# 8a1dd13368ac23f07d4fe56e6222a8b4    41
# 4e630a4877741fd57f4588ddef3d55ec    41
# f8ebc4b57a8b9b26a1a2d870d70fe28e    40
# c7623c47650fb1ade9268e2d3835655c    40
# ce87ff48d886feb4127db3609e7a3eaa    39
# fb355d872542b4c8011857715f387a40    39
# 23cf9e5846d496897886f451a4ad0a35    38
# Name: module_number, dtype: int64
